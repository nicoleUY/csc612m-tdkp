# %%
# Install libraries if needed
# !pip install ortools
# Out:
# Collecting ortools
#   Downloading ortools-9.14.6206-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (27.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.7/27.7 MB 8.9 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Collecting absl-py>=2.0.0 (from ortools)
#   Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in /home/harvsftw/miniconda3/lib/python3.11/site-packages (from ortools) (1.25.2)
# Requirement already satisfied: pandas>=2.0.0 in /home/harvsftw/miniconda3/lib/python3.11/site-packages (from ortools) (2.0.3)
# Collecting protobuf<6.32,>=6.31.1 (from ortools)
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.12 in /home/harvsftw/miniconda3/lib/python3.11/site-packages (from ortools) (4.12.2)
# Collecting immutabledict>=3.0.0 (from ortools)
#   Downloading immutabledict-4.2.2-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/harvsftw/miniconda3/lib/python3.11/site-packages (from pandas>=2.0.0->ortools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/harvsftw/miniconda3/lib/python3.11/site-packages (from pandas>=2.0.0->ortools) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/harvsftw/miniconda3/lib/python3.11/site-packages (from pandas>=2.0.0->ortools) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/harvsftw/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.16.0)
# Installing collected packages: protobuf, immutabledict, absl-py, ortools
# Successfully installed absl-py-2.3.1 immutabledict-4.2.2 ortools-9.14.6206 protobuf-6.31.1

# %%
from ortools.sat.python import cp_model

inputs = '''100 145
4 9 24 671
8 20 295 626
5 15 588 670
3 17 723 777
1 10 923 953
17 20 387 639
7 9 507 753
1 16 918 957
2 4 912 919
7 13 485 490
15 11 570 976
12 15 408 789
18 7 746 905
12 20 612 715
18 3 150 245
16 14 986 998
9 17 148 622
4 8 628 833
12 4 112 392
19 1 874 950
18 12 528 600
12 14 463 746
8 2 205 580
13 18 546 928
8 3 71 584
4 3 311 904
19 3 625 914
3 10 857 931
15 17 42 383
19 18 171 751
1 9 410 519
19 6 735 770
3 5 927 929
18 9 833 967
2 3 801 884
12 7 719 776
9 8 654 699
15 4 306 639
15 6 602 768
5 4 239 612
18 12 158 524
15 14 750 912
1 16 581 801
3 9 968 976
7 5 217 658
12 19 806 933
6 1 244 497
10 18 440 622
10 5 858 921
12 13 43 77
10 17 789 869
17 17 984 989
3 19 86 644
8 8 859 979
20 3 796 880
5 1 829 992
11 3 792 891
17 2 710 851
10 3 692 886
1 18 567 846
10 8 653 668
1 20 557 597
17 15 771 850
18 10 774 788
14 19 875 912
6 1 372 372
20 16 215 478
5 18 788 933
10 12 251 689
8 19 281 718
17 15 819 927
12 17 601 789
2 2 476 867
6 6 326 876
6 12 160 841
13 16 564 707
5 11 658 779
8 11 557 759
8 11 769 945
4 20 520 592
9 4 790 937
6 5 27 790
18 20 618 807
17 18 764 799
10 19 84 215
15 10 360 726
11 2 404 624
13 4 984 989
8 20 136 960
10 8 687 877
9 5 446 587
7 12 768 879
6 13 256 311
8 17 182 311
12 7 579 751
12 2 110 642
11 6 210 372
15 12 712 742
14 17 80 172
16 4 102 683
'''.splitlines()

n, m = map(int, inputs[0].split())
price = [int(inputs[i].split()[0]) for i in range(1, n + 1)]
demand = [int(inputs[i].split()[1]) for i in range(1, n + 1)]
left = [int(inputs[i].split()[2]) for i in range(1, n + 1)]
right = [int(inputs[i].split()[3]) for i in range(1, n + 1)]
max_time = max(right)

model = cp_model.CpModel()
x = [model.NewBoolVar(f"x_{i}") for i in range(n)]
for t in range(max_time + 1):
    model.Add(sum(demand[i] * x[i] for i in range(n) if left[i] <= t and t <= right[i]) <= m)
model.Maximize(sum(price[i] * x[i] for i in range(n)))

solver = cp_model.CpSolver()
result = solver.Solve(model)

chosen_items = [i for i in range(n) if solver.Value(x[i]) == 1]
total_value = sum(price[i] for i in chosen_items)

print(chosen_items, total_value)
# Out:
# [4, 5, 7, 8, 9, 10, 12, 14, 15, 18, 19, 20, 22, 24, 26, 28, 29, 30, 31, 32, 33, 35, 36, 37, 38, 39, 40, 41, 43, 44, 45, 46, 48, 49, 50, 51, 53, 54, 55, 56, 57, 58, 60, 62, 63, 64, 65, 66, 68, 70, 75, 76, 78, 80, 81, 82, 83, 84, 85, 86, 87, 89, 90, 92, 93, 94, 95, 96, 97, 98, 99] 841
