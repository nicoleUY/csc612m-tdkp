# %%
# Install libraries if needed
# !pip install ortools
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ortools in ./.local/lib/python3.12/site-packages (9.14.6206)
# Requirement already satisfied: absl-py>=2.0.0 in ./.local/lib/python3.12/site-packages (from ortools) (2.3.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/tljh/user/lib/python3.12/site-packages (from ortools) (2.2.6)
# Requirement already satisfied: pandas>=2.0.0 in ./.local/lib/python3.12/site-packages (from ortools) (2.3.3)
# Requirement already satisfied: protobuf<6.32,>=6.31.1 in ./.local/lib/python3.12/site-packages (from ortools) (6.31.1)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/tljh/user/lib/python3.12/site-packages (from ortools) (4.13.2)
# Requirement already satisfied: immutabledict>=3.0.0 in ./.local/lib/python3.12/site-packages (from ortools) (4.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/tljh/user/lib/python3.12/site-packages (from pandas>=2.0.0->ortools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.local/lib/python3.12/site-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.12/site-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.17.0)

# %%
from ortools.sat.python import cp_model
import time

filenames = [
    "input10.txt",
    "input25.txt",
    "input50.txt",
    "input100.txt",
    "input200.txt",
    "input250.txt",
    "input500.txt",
    "input1000.txt",
    "input2000.txt"
]

for filename in filenames:
    print(f"\n=== Solving {filename} ===\n")

    with open(filename, "r") as f:
        inputs = f.read().splitlines()

    n, m = map(int, inputs[0].split())
    price = [int(inputs[i].split()[0]) for i in range(1, n + 1)]
    demand = [int(inputs[i].split()[1]) for i in range(1, n + 1)]
    left = [int(inputs[i].split()[2]) for i in range(1, n + 1)]
    right = [int(inputs[i].split()[3]) for i in range(1, n + 1)]
    max_time = max(right)

    model = cp_model.CpModel()
    x = [model.NewBoolVar(f"x_{i}") for i in range(n)]

    for t in range(max_time + 1):
        model.Add(sum(demand[i] * x[i] for i in range(n)
                      if left[i] <= t <= right[i]) <= m)

    model.Maximize(sum(price[i] * x[i] for i in range(n)))

    solver = cp_model.CpSolver()

    start = time.time()
    result = solver.Solve(model)
    end = time.time()

    solve_time_ms = (end - start) * 1000

    chosen_items = [i for i in range(n) if solver.Value(x[i]) == 1]
    total_value = sum(price[i] for i in chosen_items)

    print(f"Results for {filename}:")
    # print("Chosen items:", chosen_items)
    print("Value:", total_value)
    # print(f"Solve time: {solve_time_ms:.2f} ms")
    print("\n-------------------------\n")
# Out:
# === Solving input10.txt ===
#
# Results for input10.txt:
# Value: 104
#
# -------------------------
#
#
# === Solving input25.txt ===
#
# Results for input25.txt:
# Value: 281
#
# -------------------------
#
#
# === Solving input50.txt ===
#
# Results for input50.txt:
# Value: 613
#
# -------------------------
#
#
# === Solving input100.txt ===
#
# Results for input100.txt:
# Value: 1188
#
# -------------------------
#
#
# === Solving input200.txt ===
#
# Results for input200.txt:
# Value: 2574
#
# -------------------------
#
#
# === Solving input250.txt ===
#
# Results for input250.txt:
# Value: 3100
#
# -------------------------
#
#
# === Solving input500.txt ===
#
# Results for input500.txt:
# Value: 6332
#
# -------------------------
#
#
# === Solving input1000.txt ===
#
# Results for input1000.txt:
# Value: 12462
#
# -------------------------
#
#
# === Solving input2000.txt ===
#
# Results for input2000.txt:
# Value: 24903
#
# -------------------------

# %%
a
